# %% [markdown]
# ![KAUST Academy](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # Day 3 -- Lab 2: Explore the Titanic
#
# You are handed the passenger list of the Titanic and one question: who survived, and what does the table say about why? Before any model (Week 2), you run the full EDA workflow: load, types, missing values, duplicates, counts, group means and two plots, and you save a clean table ready for modelling.
#
# **Your role:** Fill in the `# Your code here` cells in order. Run every cell, including the ones already written for you.
#
# **Dataset:** The Titanic passenger list from Kaggle, `yasserh/titanic-dataset` (891 rows, 12 columns). The setup cell downloads it with `kagglehub` and loads `Titanic-Dataset.csv` into a DataFrame `df`.

# %% [markdown]
# ---
# # Setup

# %%
# kagglehub, pandas and matplotlib are preinstalled on Colab. Uncomment if an import fails.
# !pip install -q kagglehub pandas matplotlib

# %%
import os
import kagglehub
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = kagglehub.dataset_download("yasserh/titanic-dataset")
df = pd.read_csv(os.path.join(path, "Titanic-Dataset.csv"))
print(df.shape)

# %% [markdown]
# ---
# # Part 1 -- Load and look

# %% [markdown]
# ## Task 1: First rows
#
# Display the first five rows with `df.head()`. Which columns are text, which are numbers, and which column is the target (what we would like to predict)?

# %%
# Your code here

# %% [markdown]
# ## Task 2: Types and non-missing counts
#
# Call `df.info()`. Three columns have fewer than 891 non-null values: which ones?

# %%
# Your code here

# %% [markdown]
# ## Task 3: Count the missing values
#
# Store `df.isna().sum()` in `missing` and print it. Expected: Age 177, Cabin 687, Embarked 2, all others 0.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert missing['Age'] == 177 and missing['Cabin'] == 687, 'missing: df.isna().sum() counts NaN per column'
print('Task 3 passed')

# %% [markdown]
# ---
# # Part 2 -- Clean
#
# Decide per column: drop the column, drop the rows, or fill. Use the *Missing Values* slide.

# %% [markdown]
# ## Task 4: Drop the Cabin column
#
# 77 percent of `Cabin` is missing, too much to fill. Replace `df` by `df.drop(columns=["Cabin"])` and print the shape. Expected: `(891, 11)`.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert 'Cabin' not in df.columns and df.shape == (891, 11), 'drop(columns=[...]) returns a new table; assign it back'
print('Task 4 passed')

# %% [markdown]
# ## Task 5: Fill the missing ages with the median
#
# Compute `median_age = df["Age"].median()` (expected 28.0), fill the missing ages with it, and print how many ages are still missing (expected 0).

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert median_age == 28.0 and df['Age'].isna().sum() == 0, 'Age: fillna(median) assigned back to the column'
print('Task 5 passed')

# %% [markdown]
# ## Task 6: Drop the two rows without a port
#
# Only 2 rows lack `Embarked`. Replace `df` by `df.dropna(subset=["Embarked"])`, then print `df.shape` and `df.isna().sum().sum()`. Expected: `(889, 11)` and 0.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert df.shape == (889, 11) and df.isna().sum().sum() == 0, 'dropna(subset=["Embarked"]) removes exactly two rows'
print('Task 6 passed')

# %% [markdown]
# ## Task 7: Check for duplicated rows
#
# Print `df.duplicated().sum()`. Expected: 0 (this table is clean in that respect; you still check).

# %%
# Your code here

# %% [markdown]
# ---
# # Part 3 -- Ask the data
#
# Counts, shares and group means from the *Counts and Means per Group* slide.

# %% [markdown]
# ## Task 8: Class balance of the target
#
# Print `df["Survived"].value_counts()` and store the survival share in `rate = df["Survived"].mean()`. Print `rate` with three decimals. Expected: about 0.382.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert 0.37 < rate < 0.40, 'rate: the mean of a 0/1 column is the share of ones'
print('Task 8 passed')

# %% [markdown]
# ## Task 9: Survival by sex
#
# Store `by_sex = df.groupby("Sex")["Survived"].mean()` and print it. Expected: female about 0.74, male about 0.19.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert by_sex['female'] > 0.7 and by_sex['male'] < 0.2, 'by_sex: groupby("Sex") then the mean of Survived'
print('Task 9 passed')

# %% [markdown]
# ## Task 10: Survival by class
#
# Store `by_class = df.groupby("Pclass")["Survived"].mean()` and print it. Expected: about 0.63, 0.47, 0.24 for classes 1, 2, 3.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert by_class[1] > by_class[2] > by_class[3], 'by_class: survival falls from first to third class'
print('Task 10 passed')

# %% [markdown]
# ## Task 11: Children versus adults
#
# Filter the rows with `Age < 18` and print their survival share, then the share for `Age >= 18`. Which group survived more often?

# %%
# Your code here

# %% [markdown]
# ---
# # Part 4 -- Plot and save

# %% [markdown]
# ## Task 12: Histogram of ages
#
# Draw a histogram of `df["Age"]` with 30 bins, a title and axis labels. You should see a tall bar at 28: the 177 filled ages.

# %%
# Your code here

# %% [markdown]
# ## Task 13: Bar chart of survival by class
#
# Draw a bar chart of `by_class` (x: the class labels as strings, `by_class.index.astype(str)`; heights: `by_class.values`), with a title and axis labels.

# %%
# Your code here

# %% [markdown]
# ## Task 14: Save the clean table
#
# Write `df` to `titanic_clean.csv` without the index (`df.to_csv("titanic_clean.csv", index=False)`), read it back with `pd.read_csv` into `check`, and print `check.shape`. Expected: `(889, 11)`.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
check = pd.read_csv('titanic_clean.csv')
assert check.shape == (889, 11) and check.isna().sum().sum() == 0, 'titanic_clean.csv: the cleaned table, written with index=False'
print('Task 14 passed')

# %% [markdown]
# ---
# ## Task 15: Reflect
#
# Sex and class both move survival a lot. If on Friday you had to predict survival with one rule, which column would you use and what rule? The tall bar at age 28 is an artefact of filling: name one way it could mislead a model, and one alternative to filling with a single value.

# %% [markdown]
# *Your answers here*

# %% [markdown]
# ---
# ## Conclusion
#
# - **Load and look**: you read a real 891-row table and found its types and missing values before changing anything.
# - **Clean**: you dropped a hopeless column, filled ages with the median, dropped two rows, and checked for duplicates, in the workflow order.
# - **Ask the data**: you measured the class balance and survival by sex, class and age with `value_counts`, `groupby` and filters.
# - **Plot and save**: you drew a histogram and a bar chart with labels and saved a clean table for Week 2.

# %% [markdown]
# ---
#
# Made By **Sattam Altwaim**
