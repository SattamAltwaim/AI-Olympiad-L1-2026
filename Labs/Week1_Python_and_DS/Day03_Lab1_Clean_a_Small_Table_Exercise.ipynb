# %% [markdown]
# ![KAUST Academy](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # Day 3 -- Lab 1: Clean a Small Table
#
# The quiz scoreboard from Saturday came back from three different helpers, and it shows: one student appears twice, one score is written as text, and two scores are missing. You will load it into a DataFrame, find each problem with one call, fix it with one call, and end with a clean table and a first plot.
#
# **Your role:** Fill in the `# Your code here` cells in order. Run every cell, including the ones already written for you.
#
# **Dataset:** No download. The dirty scoreboard is typed into the setup cell as a dictionary of columns (seven rows).

# %% [markdown]
# ---
# # Setup

# %%
# pandas and matplotlib are preinstalled on Colab.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "name":   ["Ali", "Sara", "Omar", "Omar", "Lina", "Yara", "Faisal"],
    "round1": [78, 92, 85, 85, 64, 91, 55],
    "round2": ["82", "n/a", "79", "79", "70", "95", "61"],   # text!
    "round3": [75, 96, 90, 90, None, 89, 49],                 # None becomes NaN
}

# %% [markdown]
# ---
# # Part 1 -- Load and look
#
# The *Pandas* slides: build the table, then describe it before touching anything.

# %% [markdown]
# ## Task 1: Build the DataFrame
#
# Create `df = pd.DataFrame(data)` and display it (just write `df` as the last line of the cell). You should see 7 rows and 4 columns, with `NaN` in Lina's round 3.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert df.shape == (7, 4), 'df: pd.DataFrame(data) gives 7 rows and 4 columns'
print('Task 1 passed')

# %% [markdown]
# ## Task 2: Shape and types
#
# Print `df.shape` and `df.dtypes`. Which column is `object` (text) although it should hold numbers?

# %%
# Your code here

# %% [markdown]
# ## Task 3: Count the missing values
#
# Print `df.isna().sum()`. Expected: round3 has 1 missing value and the other columns 0 (the `"n/a"` in round2 is text, so pandas does not see it as missing yet).

# %%
# Your code here

# %% [markdown]
# ---
# # Part 2 -- Clean
#
# The *Data Cleaning* slides, in the workflow order: types, missing values, duplicates. Each fix is one call; remember to assign the result back to `df` or to the column.

# %% [markdown]
# ## Task 4: Fix the text column
#
# Convert `round2` to numbers with `pd.to_numeric(..., errors="coerce")` and store it back in `df["round2"]`. Print `df.dtypes` and `df.isna().sum()` again: round2 is now `float64` with 1 missing value.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert df['round2'].dtype != object, 'round2: pd.to_numeric with errors="coerce", assigned back to the column'
assert df['round2'].isna().sum() == 1, 'round2: the n/a entry should have become NaN'
print('Task 4 passed')

# %% [markdown]
# ## Task 5: Remove the duplicated row
#
# Print `df.duplicated().sum()` (expected 1), then replace `df` by `df.drop_duplicates().reset_index(drop=True)` (drop the copy, then renumber the rows 0 to 5). Print the new shape. Expected: `(6, 4)`.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert df.shape == (6, 4) and list(df.index) == [0, 1, 2, 3, 4, 5], 'df: drop_duplicates().reset_index(drop=True), assigned back with df = ...'
print('Task 5 passed')

# %% [markdown]
# ## Task 6: Fill the missing scores with the column mean
#
# For each of `round2` and `round3`, fill the missing value with that column's mean (`df[col].fillna(df[col].mean())`, assigned back). Print `df.isna().sum().sum()` (expected 0) and the table. Sara's round2 should be 77.4 and Lina's round3 79.8.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert df.isna().sum().sum() == 0, 'no NaN may remain after filling'
assert abs(df.loc[df['name'] == 'Sara', 'round2'].iloc[0] - 77.4) < 0.01, 'round2: the mean of the five present scores is 77.4'
print('Task 6 passed')

# %% [markdown]
# ---
# # Part 3 -- Summarise and plot

# %% [markdown]
# ## Task 7: Add an average column and sort
#
# Create `df["average"]` as the mean of the three round columns (`(df["round1"] + df["round2"] + df["round3"]) / 3`), then display `df.sort_values("average", ascending=False)`. Yara should be first (Sara's filled round 2 pulls her down).

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert df.sort_values('average', ascending=False)['name'].iloc[0] == 'Yara', 'average: the mean of the three rounds; Yara has the highest (91.7)'
print('Task 7 passed')

# %% [markdown]
# ## Task 8: Describe the numbers
#
# Display `df.describe()` and read off the mean and the standard deviation of `average`.

# %%
# Your code here

# %% [markdown]
# ## Task 9: Passed or not, counted
#
# Create a column `passed` that is `True` when `average >= 60`, then print `df["passed"].value_counts()`. Expected: 5 True, 1 False.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert df['passed'].sum() == 5, 'passed: average >= 60 is True for five students'
print('Task 9 passed')

# %% [markdown]
# ## Task 10: A bar chart of the averages
#
# Draw a bar chart with the student names on the x axis and their averages as bar heights (`ax.bar(df["name"], df["average"])`), with a title and axis labels (*Plots in Code* slide).

# %%
# Your code here

# %% [markdown]
# ---
# ## Task 11: Reflect
#
# You filled two missing scores with column means. Give one reason this is reasonable here and one situation where it would be a bad idea. If you had dropped the rows instead, how would the bar chart and the pass count have changed?

# %% [markdown]
# *Your answers here*

# %% [markdown]
# ---
# ## Conclusion
#
# - **Load and look**: you built a DataFrame and read its shape, types and missing counts before changing anything.
# - **Clean**: you fixed a text column with `to_numeric`, removed a duplicated row, and filled missing values with column means, in the workflow order.
# - **Summarise and plot**: you added a computed column, sorted, described, counted a boolean column and drew a labelled bar chart.

# %% [markdown]
# ---
#
# Made By **Sattam Altwaim**
