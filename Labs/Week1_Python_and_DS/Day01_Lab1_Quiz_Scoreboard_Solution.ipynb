# %% [markdown]
# ![KAUST Academy](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # Day 1 -- Lab 1: Quiz Scoreboard (Solution)
#
# Your class ran a quiz with three rounds. You are the scorekeeper, and the teacher wants the averages, the grades and the winner by the end of the day. You will build the scoreboard with plain Python, one idea from today's slides at a time: variables, strings, lists, loops, dictionaries, functions, and finally a small class.
#
# **Your role:** Fill in the `# Your code here` cells in order. Run every cell, including the ones already written for you.
#
# **Dataset:** No file to download. The six students and their three round scores are typed into the setup cell below, so you can print everything and check it by eye.

# %% [markdown]
# ---
# # Setup

# %%
# Nothing to install: this lab uses plain Python only.

# %%
names  = ["Ali", "Sara", "Omar", "Lina", "Yara", "Faisal"]
round1 = [78, 92, 85, 64, 91, 55]
round2 = [82, 88, 79, 70, 95, 61]
round3 = [75, 96, 90, 58, 89, 49]
print(names)
print(round1)

# %% [markdown]
# ---
# # Part 1 -- Variables and strings
#
# We start with one student, Sara, and her three scores: 92, 88 and 96. Everything here is one line each, exactly like the *Variables and Types* and *Numbers and Strings* slides.

# %% [markdown]
# ## Task 1: Store Sara's scores in variables
#
# Create four variables: `name` holding the text `"Sara"`, and `r1`, `r2`, `r3` holding the numbers 92, 88 and 96. Then print `name` and `type(name)` on one line. The output should be `Sara <class 'str'>`.

# %%
# Solution
name = "Sara"
r1 = 92
r2 = 88
r3 = 96
print(name, type(name))

# %% [markdown]
# ## Task 2: Build a sentence with an f-string
#
# Make a variable `message` that uses an f-string to produce exactly `Sara scored 92, 88 and 96.` from the four variables (do not type the numbers again). Print it.

# %%
# Solution
message = f"{name} scored {r1}, {r2} and {r3}."
print(message)

# %% [markdown]
# ## Task 3: Total and average
#
# Compute `total` (the three scores added) and `average` (the total divided by 3). Print both on one line. Expected: `276 92.0`. This is the average formula from the slides with Sara's numbers plugged in.

# %%
# Solution
total = r1 + r2 + r3
average = total / 3
print(total, average)

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert total == 276, 'total: add the three scores r1 + r2 + r3'
assert abs(average - 92.0) < 1e-9, 'average: divide the total by 3, not by 2 or 4'
print('Task 3 passed')

# %% [markdown]
# ## Task 4: Grade the average
#
# Write an `if` / `elif` / `else` chain that stores a letter in `grade`: `"A"` for an average of 90 or more, `"B"` for 80 or more, `"C"` for 70 or more, and `"F"` otherwise. Print `grade`. For Sara it must be `A`.

# %%
# Solution
if average >= 90:
    grade = "A"
elif average >= 80:
    grade = "B"
elif average >= 70:
    grade = "C"
else:
    grade = "F"
print(grade)

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert grade == 'A', 'grade: an average of 92.0 is 90 or more, so the first branch should run'
print('Task 4 passed')

# %% [markdown]
# ---
# # Part 2 -- Lists and loops
#
# Now the whole class. `round1` is a list of six scores in the same order as `names`. We index it, extend it, and then add it up by hand with the accumulator pattern from the *Loops* slides.

# %% [markdown]
# ## Task 5: Index and slice the round 1 scores
#
# From `round1`, store the first score in `first`, the last score in `last`, and the scores at positions 1, 2 and 3 in `middle` (one slice). Print the three variables. Expected: `78 55 [92, 85, 64]`.

# %%
# Solution
first = round1[0]
last = round1[-1]
middle = round1[1:4]
print(first, last, middle)

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert first == 78 and last == 55, 'first/last: index 0 is the first item, index -1 the last'
assert middle == [92, 85, 64], 'middle: a slice [1:4] takes indices 1, 2 and 3'
print('Task 5 passed')

# %% [markdown]
# ## Task 6: Add a late student
#
# Noor joined late and scored 73 in round 1. Make a copy of the list with `scores = list(round1)` (so `round1` stays untouched), then append 73 to `scores`. Print `scores` and its length. Expected length: 7.

# %%
# Solution
scores = list(round1)
scores.append(73)
print(scores, len(scores))

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert len(scores) == 7 and scores[-1] == 73, 'scores: append adds one item at the end'
assert len(round1) == 6, 'round1 must stay unchanged: copy it with list(round1) first'
print('Task 6 passed')

# %% [markdown]
# ## Task 7: Add the scores up with a loop
#
# Without using `sum()`, compute `total` with the accumulator pattern: start at 0, loop over `scores`, add each score. Then compute `average = total / len(scores)`. Print both. Expected: `538 76.857...`.

# %%
# Solution
total = 0
for s in scores:
    total = total + s
average = total / len(scores)
print(total, average)

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert total == sum(scores), 'total: start at 0 before the loop and add every score inside it'
assert abs(average - total / 7) < 1e-9, 'average: divide by len(scores), which is 7'
print('Task 7 passed')

# %% [markdown]
# ## Task 8: Find the best score with a loop
#
# Without using `max()`, find the largest value in `scores` and store it in `best`. Start with `best = scores[0]` and replace it whenever the loop meets a bigger score. Print `best`. Expected: 92.

# %%
# Solution
best = scores[0]
for s in scores:
    if s > best:
        best = s
print(best)

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert best == max(scores), 'best: replace best only when the current score is bigger'
print('Task 8 passed')

# %% [markdown]
# ## Task 9: Count how many passed
#
# A score of 60 or more is a pass. Loop over `scores` and count the passes in `n_passed` (start at 0, add 1 inside an `if`). Print it. Expected: 6.

# %%
# Solution
n_passed = 0
for s in scores:
    if s >= 60:
        n_passed = n_passed + 1
print(n_passed)

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert n_passed == 6, 'n_passed: count scores that are 60 or more (>= 60, not > 60)'
print('Task 9 passed')

# %% [markdown]
# ---
# # Part 3 -- Dictionaries and functions
#
# Three lists in the same order are hard to keep straight. A dictionary gives each student a key, and functions let us reuse the average and the grade rule.

# %% [markdown]
# ## Task 10: Build a dictionary of averages
#
# Create a dictionary `averages` that maps each name to the average of that student's three rounds. Loop over `range(len(names))` so the index `i` reads `names[i]`, `round1[i]`, `round2[i]` and `round3[i]`. Print the dictionary. Sara's value must be `92.0`.
#
# Syntax hint (the shape of the call, not the answer):
#
# ```python
# for i in range(len(some_list)):
#     result[key_list[i]] = value_list[i] * 2
# ```

# %%
# Solution
averages = {}
for i in range(len(names)):
    averages[names[i]] = (round1[i] + round2[i] + round3[i]) / 3
print(averages)

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert len(averages) == 6, 'averages: one key per student, six in total'
assert abs(averages['Sara'] - 92.0) < 1e-9, 'averages: add the three rounds for index i and divide by 3'
print('Task 10 passed')

# %% [markdown]
# ## Task 11: Print the scoreboard
#
# Loop over `averages.items()` and print one line per student in the form `Ali: 78.3` (one decimal, use an f-string with `:.1f`).

# %%
# Solution
for name, avg in averages.items():
    print(f"{name}: {avg:.1f}")

# %% [markdown]
# ## Task 12: Write a grade function
#
# Turn the `if` chain from Task 4 into a function `grade(score)` that returns `"A"`, `"B"`, `"C"` or `"F"` with the same rule. Then print `grade(95)` and `grade(45)`. Expected: `A F`.

# %%
# Solution
def grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    else:
        return "F"

print(grade(95), grade(45))

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert grade(95) == 'A' and grade(85) == 'B' and grade(75) == 'C' and grade(45) == 'F', 'grade: check the four thresholds 90, 80, 70'
assert grade(90) == 'A', 'grade: 90 exactly is an A (use >=, not >)'
print('Task 12 passed')

# %% [markdown]
# ## Task 13: Write an average function
#
# Write a function `average(scores)` that takes a list and returns its mean, using the accumulator loop from Task 7 inside the function (no `sum()`). Print `average([78, 92, 85])`. Expected: `85.0`.

# %%
# Solution
def average(scores):
    total = 0
    for s in scores:
        total = total + s
    return total / len(scores)

print(average([78, 92, 85]))

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert abs(average([78, 92, 85]) - 85.0) < 1e-9, 'average: return total divided by len(scores)'
assert abs(average([10]) - 10.0) < 1e-9, 'average: a list with one item returns that item'
print('Task 13 passed')

# %% [markdown]
# ## Task 14: Count the grades
#
# Using the counting pattern from the *Dictionaries* slides, build a dictionary `grade_counts` that says how many students got each letter. Loop over `averages.values()`, call `grade()` on each value, and add 1 to that letter's counter (start a new counter at 1). Print it. Expected: `{'C': 1, 'A': 2, 'B': 1, 'F': 2}` (the order may differ).

# %%
# Solution
grade_counts = {}
for avg in averages.values():
    letter = grade(avg)
    if letter in grade_counts:
        grade_counts[letter] = grade_counts[letter] + 1
    else:
        grade_counts[letter] = 1
print(grade_counts)

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert grade_counts == {'A': 2, 'B': 1, 'C': 1, 'F': 2}, 'grade_counts: known letter adds 1, new letter starts at 1'
print('Task 14 passed')

# %% [markdown]
# ---
# # Part 4 -- A first object
#
# A student is a name plus a list of scores, and the things we do with a student (average, grade) belong together. That is what a class is for (*Classes and Objects* slides). If the session runs out of time, finish this part at home before Sunday.

# %% [markdown]
# ## Task 15: Write a Student class
#
# Write a class `Student` with an `__init__(self, name, scores)` that stores both as attributes, and a method `average(self)` that returns the mean of `self.scores` (you may call your `average` function from Task 13 inside it). Then create `s = Student("Sara", [92, 88, 96])` and print `s.name` and `s.average()`. Expected: `Sara 92.0`.
#
# Syntax hint (the shape of the call, not the answer):
#
# ```python
# class Thing:
#     def __init__(self, a, b):
#         self.a = a
#         self.b = b
#
#     def describe(self):
#         return f"{self.a} and {self.b}"
# ```

# %%
# Solution
class Student:
    def __init__(self, name, scores):
        self.name = name
        self.scores = scores

    def average(self):
        return average(self.scores)   # reuse the function from Task 13

s = Student("Sara", [92, 88, 96])
print(s.name, s.average())

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert s.name == 'Sara' and abs(s.average() - 92.0) < 1e-9, 'Student: store name and scores in __init__, average() returns the mean of self.scores'
print('Task 15 passed')

# %% [markdown]
# ## Task 16: Build all students and find the winner
#
# Build a list `students` with one `Student` per name, using a loop over `range(len(names))` and the three round lists. Then loop over `students` to find the one with the highest average and store that object in `winner`. Print `winner.name`. Expected: `Sara`.

# %%
# Solution
students = []
for i in range(len(names)):
    students.append(Student(names[i], [round1[i], round2[i], round3[i]]))

winner = students[0]
for st in students:
    if st.average() > winner.average():
        winner = st
print(winner.name, winner.average())

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert len(students) == 6, 'students: one Student object per name'
assert winner.name == 'Sara', 'winner: keep the student whose average() is largest'
print('Task 16 passed')

# %% [markdown]
# ---
# ## Task 17: Reflect
#
# In Part 3 you kept three parallel lists and a dictionary; in Part 4 each student became one object. In your own words, what mistake becomes impossible with the object version that was easy to make with the lists? Which of the two versions would you rather extend with a fourth round, and why?

# %% [markdown]
# *Your answers here*

# %% [markdown]
# ---
# ## Conclusion
#
# - **Variables and types**: you stored text and numbers, converted between them in your head, and printed with f-strings.
# - **Lists and loops**: you indexed and sliced a list, then added, searched and counted with the accumulator pattern instead of built-ins.
# - **Dictionaries and functions**: you mapped names to averages, counted grades with a counter dictionary, and turned repeated code into `grade()` and `average()`.
# - **Classes and objects**: you wrote a `Student` blueprint, built six objects from it, and found the winner with a loop over objects.

# %% [markdown]
# ---
#
# Made By **Sattam Altwaim**
