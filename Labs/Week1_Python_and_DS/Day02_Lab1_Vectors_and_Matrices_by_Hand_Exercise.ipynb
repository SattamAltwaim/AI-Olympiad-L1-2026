# %% [markdown]
# ![KAUST Academy](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # Day 2 -- Lab 1: Vectors and Matrices by Hand
#
# Before letting NumPy do the work, you will build every operation from today's slides with plain Python on two real flowers and a tiny matrix: add, scale, dot product, norm, distance, mean, standard deviation, transpose and matrix products. At the end you check each one against NumPy.
#
# **Your role:** Fill in the `# Your code here` cells in order. Run every cell, including the ones already written for you.
#
# **Dataset:** No download. The two flowers are rows 1 and 101 of the Iris data set (a setosa and a virginica), typed into the setup cell as lists of four measurements.

# %% [markdown]
# ---
# # Setup

# %%
# Nothing to install: plain Python and math, NumPy only in the last part.

# %%
import math

setosa    = [5.1, 3.5, 1.4, 0.2]   # sepal length, sepal width, petal length, petal width (cm)
virginica = [6.3, 3.3, 6.0, 2.5]
scores    = [78, 92, 85, 64, 91]
print(len(setosa), len(virginica))

# %% [markdown]
# ---
# # Part 1 -- Vector operations
#
# Each flower is a 4-dimensional vector. Every operation in this part is a loop over the four entries, exactly as on the *Scalars and Vectors* and *Dot Product* slides.

# %% [markdown]
# ## Task 1: Vector addition
#
# Compute `total = setosa + virginica` as a vector (entry by entry) with a loop or a list comprehension over `zip(setosa, virginica)`. Print it. Expected: `[11.4, 6.8, 7.4, 2.7]`. Note that `setosa + virginica` with the plain `+` would glue the lists instead.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert len(total) == 4, 'total: one entry per measurement, four in total (zip, not list +)'
assert abs(total[2] - 7.4) < 1e-9, 'total: add the entries pairwise: 1.4 + 6.0 = 7.4'
print('Task 1 passed')

# %% [markdown]
# ## Task 2: Scalar multiplication
#
# Compute `half = 0.5 * setosa` as a vector: every entry multiplied by 0.5. Print it. Expected: `[2.55, 1.75, 0.7, 0.1]`.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert all(abs(h - 0.5 * a) < 1e-9 for h, a in zip(half, setosa)), 'half: multiply every entry by 0.5'
print('Task 2 passed')

# %% [markdown]
# ## Task 3: The dot product
#
# Write a function `dot(a, b)` that returns the dot product of two lists (multiply pairs, add up, accumulator pattern). Print `dot([1, 2, 3], [4, 5, 6])` and `dot(setosa, virginica)`. Expected: `32` and about `52.58`.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert dot([1, 2, 3], [4, 5, 6]) == 32, 'dot: 1*4 + 2*5 + 3*6 = 32'
assert abs(dot(setosa, virginica) - 52.58) < 0.01, 'dot: multiply matching entries, then add all four products'
print('Task 3 passed')

# %% [markdown]
# ## Task 4: The norm
#
# Write `norm(a)` that returns the length of a vector: the square root (`math.sqrt`) of the dot product of `a` with itself. Print `norm([3, 4])` and `norm(setosa)`. Expected: `5.0` and about `6.35`.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert abs(norm([3, 4]) - 5.0) < 1e-9, 'norm: sqrt(3*3 + 4*4) = 5'
print('Task 4 passed')

# %% [markdown]
# ## Task 5: The distance between two flowers
#
# Write `distance(a, b)` that returns the norm of `a - b` (subtract entry by entry, then call `norm`). Print `distance([1, 1], [4, 5])` and `distance(setosa, virginica)`. Expected: `5.0` and about `5.28`.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert abs(distance([1, 1], [4, 5]) - 5.0) < 1e-9, 'distance: norm of the entry-wise difference'
assert abs(distance(setosa, virginica) - 5.285) < 0.01, 'distance: subtract first (a - b), then take the norm'
print('Task 5 passed')

# %% [markdown]
# ---
# # Part 2 -- Mean and spread
#
# The five quiz scores from the *Math Foundations* slides: mean 82, variance 106, standard deviation about 10.3.

# %% [markdown]
# ## Task 6: The mean
#
# Write `mean(xs)` using a loop (no `sum()`), and print `mean(scores)`. Expected: `82.0`.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert abs(mean(scores) - 82.0) < 1e-9, 'mean: the sum divided by the count'
print('Task 6 passed')

# %% [markdown]
# ## Task 7: Variance and standard deviation
#
# Write `std(xs)`: compute the mean, then the average of the squared differences `(x - m) ** 2` with a loop (that is the variance), then return its square root. Print the variance and `std(scores)`. Expected: variance `106.0`, standard deviation about `10.30`.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert abs(std(scores) - math.sqrt(106)) < 1e-6, 'std: average the squared differences from the mean, then square root'
print('Task 7 passed')

# %% [markdown]
# ---
# # Part 3 -- Matrices
#
# A matrix is a list of rows. The examples are the ones from the *Matrices* and *Matrix Multiplication* slides, so you can check every number against them.

# %%
A = [[1, 2, 3],
     [4, 5, 6]]
B = [[5, 6],
     [7, 8]]
S = [[1, 2],
     [3, 4]]
print(A[1][2])   # row 1, column 2 -> 6

# %% [markdown]
# ## Task 8: Shape
#
# Write `shape(M)` that returns a tuple `(rows, columns)` of a list-of-rows matrix. Print `shape(A)` and `shape(B)`. Expected: `(2, 3)` and `(2, 2)`.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert shape(A) == (2, 3) and shape(B) == (2, 2), 'shape: (number of rows, length of one row)'
print('Task 8 passed')

# %% [markdown]
# ## Task 9: Transpose
#
# Write `transpose(M)` that returns a new matrix whose row `j` is column `j` of `M` (a loop over columns, inside it a loop over rows). Print `transpose(A)`. Expected: `[[1, 4], [2, 5], [3, 6]]`.
#
# Syntax hint (the shape of the call, not the answer):
#
# ```python
# # building a list of lists one row at a time
# result = []
# for j in range(n):
#     result.append([something for i in range(m)])
# ```

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert transpose(A) == [[1, 4], [2, 5], [3, 6]], 'transpose: entry (i, j) of A becomes entry (j, i)'
assert shape(transpose(A)) == (3, 2), 'transpose: a 2x3 matrix becomes 3x2'
print('Task 9 passed')

# %% [markdown]
# ## Task 10: Matrix times vector
#
# Write `matvec(M, v)`: one dot product per row of `M` with `v`, collected in a list. Use your `dot` from Task 3. Print `matvec(A, [1, 1, 1])`. Expected: `[6, 15]`.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert matvec(A, [1, 1, 1]) == [6, 15], 'matvec: row (1,2,3) dot (1,1,1) = 6, row (4,5,6) dot (1,1,1) = 15'
print('Task 10 passed')

# %% [markdown]
# ## Task 11: Matrix times matrix
#
# Write `matmul(M, N)`: entry `(i, j)` is the dot product of row `i` of `M` with column `j` of `N`. Hint: the columns of `N` are the rows of `transpose(N)`. Print `matmul(S, B)`. Expected: `[[19, 22], [43, 50]]`.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert matmul(S, B) == [[19, 22], [43, 50]], 'matmul: entry (i, j) = row i of the left matrix dot column j of the right one'
print('Task 11 passed')

# %% [markdown]
# ---
# # Part 4 -- The same in NumPy
#
# Now the one-line versions from the *NumPy Arrays* slides. Each check compares NumPy with your own functions.

# %%
import numpy as np

s = np.array(setosa)
v = np.array(virginica)
A_np = np.array(A)
S_np = np.array(S)
B_np = np.array(B)
print(s.shape, A_np.shape)

# %% [markdown]
# ## Task 12: Vector operations in NumPy
#
# Using the arrays `s` and `v`, compute the sum `s + v`, the dot product `s @ v` and the distance `np.linalg.norm(s - v)`. Print all three; they must equal Tasks 1, 3 and 5.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert abs((s @ v) - dot(setosa, virginica)) < 1e-9, 'NumPy dot: s @ v (not s * v, which is entry-wise)'
assert abs(np.linalg.norm(s - v) - distance(setosa, virginica)) < 1e-9, 'NumPy distance: norm of s - v'
print('Task 12 passed')

# %% [markdown]
# ## Task 13: Matrix operations in NumPy
#
# Compute `A_np.T`, `A_np @ np.array([1, 1, 1])` and `S_np @ B_np`. Print them; they must equal Tasks 9, 10 and 11. Then try `A_np @ B_np` and read the error message.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
assert (A_np.T == np.array(transpose(A))).all(), 'transpose: A_np.T'
assert (S_np @ B_np == np.array(matmul(S, B))).all(), 'matmul: S_np @ B_np'
print('Task 13 passed')

# %% [markdown]
# ## Task 14: Statistics in NumPy
#
# With `sc = np.array(scores)`, print `sc.mean()` and `sc.std()`. They must equal Tasks 6 and 7.

# %%
# Your code here

# %% [markdown]
# Run the check cell. It prints a message only when something needs another look.

# %%
sc = np.array(scores)
assert abs(sc.std() - std(scores)) < 1e-9, 'std: NumPy .std() divides by n, like your function'
print('Task 14 passed')

# %% [markdown]
# ---
# ## Task 15: Reflect
#
# You wrote about 40 lines of loops in Parts 1 to 3 and replaced them with 8 lines of NumPy in Part 4. Which loop was the hardest to get right, and what did the NumPy version do to make that mistake impossible? Where would you still want the loop version (think about understanding versus speed)?

# %% [markdown]
# *Your answers here*

# %% [markdown]
# ---
# ## Conclusion
#
# - **Vectors**: you added, scaled, dotted and measured two real flowers as 4-dimensional vectors, and computed the distance between them.
# - **Mean and spread**: you wrote the mean and standard deviation as loops and got the slide's numbers (82 and 10.3).
# - **Matrices**: you built shape, transpose, matrix-vector and matrix-matrix products from the dot product.
# - **NumPy**: you reproduced every result with `+`, `@`, `.T`, `np.linalg.norm`, `.mean()` and `.std()`, and read a shape error.

# %% [markdown]
# ---
#
# Made By **Sattam Altwaim**
